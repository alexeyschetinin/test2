# %% [markdown]
# Годный красный цвет!

# %%
import cv2
import numpy as np
import os

def detect_and_fill_black_rectangles(image_path, black_threshold=60, min_area=1100, merge_distance=1):
    # Проверка существования файла
    if not os.path.exists(image_path):
        print(f"Ошибка: Файл '{image_path}' не найден.")
        return

    # Загрузка изображения
    image = cv2.imread(image_path)
    if image is None:
        print("Ошибка: Не удалось загрузить изображение. Проверьте целостность файла.")
        return

    # Преобразование изображения в grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Бинаризация изображения для выделения черных областей
    _, binary = cv2.threshold(gray, black_threshold, 255, cv2.THRESH_BINARY_INV)

    # Поиск контуров
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Фильтрация контуров по площади
    filtered_contours = [cnt for cnt in contours if cv2.contourArea(cnt) > min_area]

    # Если контуров нет, выходим
    if not filtered_contours:
        print("Не найдено подходящих черных областей.")
        return

    # Объединение близких контуров
    merged_contours = []
    for contour in filtered_contours:
        x, y, w, h = cv2.boundingRect(contour)
        merged = False
        for i, merged_contour in enumerate(merged_contours):
            mx, my, mw, mh = cv2.boundingRect(merged_contour)
            # Если текущий контур близок к уже объединенному, объединяем их
            if (abs(x - mx) < merge_distance and abs(y - my) < merge_distance):
                merged_contours[i] = np.vstack((merged_contour, contour))
                merged = True
                break
        if not merged:
            merged_contours.append(contour)

    # Создание маски для заливки
    mask = np.zeros_like(gray)
    for contour in merged_contours:
        cv2.drawContours(mask, [contour], -1, 255, -1)  # Заливаем контуры белым цветом

    # Заливка красным цветом
    image[mask == 255] = (0, 0, 255)  # Заливаем маску красным цветом

    # Генерация имени выходного файла
    directory, filename = os.path.split(image_path)  # Разделение пути на директорию и имя файла
    name, ext = os.path.splitext(filename)  # Разделение имени файла и расширения
    output_filename = f"{name}_red_filled{ext}"  # Добавление суффикса
    output_path = os.path.join(directory, output_filename)  # Полный путь для сохранения

    # Сохранение результата
    cv2.imwrite(output_path, image)
    print(f"Изображение сохранено как {output_path}")

# Пример использования
image_path = 'Копия IMG_6303.jpg'
detect_and_fill_black_rectangles(image_path)
# Out:
# Изображение сохранено как Копия IMG_6303_red_filled.jpg

# %% [markdown]
# Заменяем красные области доминирующим цветом со сглаживанием

# %%
import cv2
import numpy as np
import os

def detect_and_fill_black_areas(image_path, black_threshold=5, min_area=1000, merge_distance=10, inpaint_radius=3):
    # Проверка существования файла
    if not os.path.exists(image_path):
        print(f"Ошибка: Файл '{image_path}' не найден.")
        return

    # Загрузка изображения
    image = cv2.imread(image_path)
    if image is None:
        print("Ошибка: Не удалось загрузить изображение. Проверьте целостность файла.")
        return

    # Преобразование изображения в grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Бинаризация изображения для выделения черных областей
    _, binary = cv2.threshold(gray, black_threshold, 255, cv2.THRESH_BINARY_INV)

    # Поиск контуров
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Фильтрация контуров по площади
    filtered_contours = [cnt for cnt in contours if cv2.contourArea(cnt) > min_area]

    # Если контуров нет, выходим
    if not filtered_contours:
        print("Не найдено подходящих черных областей.")
        return

    # Объединение близких контуров
    merged_contours = []
    for contour in filtered_contours:
        x, y, w, h = cv2.boundingRect(contour)
        merged = False
        for i, merged_contour in enumerate(merged_contours):
            mx, my, mw, mh = cv2.boundingRect(merged_contour)
            # Если текущий контур близок к уже объединенному, объединяем их
            if (abs(x - mx) < merge_distance and abs(y - my) < merge_distance):
                merged_contours[i] = np.vstack((merged_contour, contour))
                merged = True
                break
        if not merged:
            merged_contours.append(contour)

    # Создание маски для заливки
    mask = np.zeros_like(gray)
    for contour in merged_contours:
        cv2.drawContours(mask, [contour], -1, 255, -1)  # Заливаем контуры белым цветом

    # Определение доминирующего цвета для каждой области
    for contour in merged_contours:
        # Получаем ограничивающий прямоугольник для контура
        x, y, w, h = cv2.boundingRect(contour)

        # Расширяем область для анализа окружения
        expand_size = 10  # Размер расширения для анализа окружения
        x1 = max(x - expand_size, 0)
        y1 = max(y - expand_size, 0)
        x2 = min(x + w + expand_size, image.shape[1])
        y2 = min(y + h + expand_size, image.shape[0])

        # Вырезаем область для анализа
        roi = image[y1:y2, x1:x2]

        # Определяем доминирующий цвет в окружении
        dominant_color = np.array(cv2.mean(roi)[:3], dtype=np.uint8)

        # Заливаем область доминирующим цветом
        cv2.drawContours(image, [contour], -1, dominant_color.tolist(), -1)

    # Сглаживание границ с помощью inpainting
    image = cv2.inpaint(image, mask, inpaintRadius=inpaint_radius, flags=cv2.INPAINT_TELEA)

    # Генерация имени выходного файла
    directory, filename = os.path.split(image_path)  # Разделение пути на директорию и имя файла
    name, ext = os.path.splitext(filename)  # Разделение имени файла и расширения
    output_filename = f"{name}_filled{ext}"  # Добавление суффикса
    output_path = os.path.join(directory, output_filename)  # Полный путь для сохранения

    # Сохранение результата
    cv2.imwrite(output_path, image)
    print(f"Изображение сохранено как {output_path}")

# Пример использования
image_path = 'blood_analysis_dataset_540/paper/Копия IMG_6308.jpg'
detect_and_fill_black_areas(image_path)
# Out:
# Изображение сохранено как blood_analysis_dataset_540/paper/Копия IMG_6308_filled.jpg

# %% [markdown]
# Добавим пакетной обработки

# %%
import cv2
import numpy as np
import os
import shutil

def detect_and_fill_black_areas(image_path, output_path, black_threshold=5, min_area=1000, merge_distance=10, inpaint_radius=3):
    # Загрузка изображения
    image = cv2.imread(image_path)
    if image is None:
        print(f"Ошибка: Не удалось загрузить изображение {image_path}. Проверьте целостность файла.")
        return False

    # Преобразование изображения в grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Бинаризация изображения для выделения черных областей
    _, binary = cv2.threshold(gray, black_threshold, 255, cv2.THRESH_BINARY_INV)

    # Поиск контуров
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Фильтрация контуров по площади
    filtered_contours = [cnt for cnt in contours if cv2.contourArea(cnt) > min_area]

    # Если контуров нет, копируем файл в папку обработанных файлов
    if not filtered_contours:
        print(f"Не найдено подходящих черных областей в {image_path}. Файл будет скопирован.")
        shutil.copy(image_path, output_path)
        return False

    # Объединение близких контуров
    merged_contours = []
    for contour in filtered_contours:
        x, y, w, h = cv2.boundingRect(contour)
        merged = False
        for i, merged_contour in enumerate(merged_contours):
            mx, my, mw, mh = cv2.boundingRect(merged_contour)
            # Если текущий контур близок к уже объединенному, объединяем их
            if (abs(x - mx) < merge_distance and abs(y - my) < merge_distance):
                merged_contours[i] = np.vstack((merged_contour, contour))
                merged = True
                break
        if not merged:
            merged_contours.append(contour)

    # Создание маски для заливки
    mask = np.zeros_like(gray)
    for contour in merged_contours:
        cv2.drawContours(mask, [contour], -1, 255, -1)  # Заливаем контуры белым цветом

    # Определение доминирующего цвета для каждой области
    for contour in merged_contours:
        # Получаем ограничивающий прямоугольник для контура
        x, y, w, h = cv2.boundingRect(contour)

        # Расширяем область для анализа окружения
        expand_size = 10  # Размер расширения для анализа окружения
        x1 = max(x - expand_size, 0)
        y1 = max(y - expand_size, 0)
        x2 = min(x + w + expand_size, image.shape[1])
        y2 = min(y + h + expand_size, image.shape[0])

        # Вырезаем область для анализа
        roi = image[y1:y2, x1:x2]

        # Определяем доминирующий цвет в окружении
        dominant_color = np.array(cv2.mean(roi)[:3], dtype=np.uint8)

        # Заливаем область доминирующим цветом
        cv2.drawContours(image, [contour], -1, dominant_color.tolist(), -1)

    # Сглаживание границ с помощью inpainting
    image = cv2.inpaint(image, mask, inpaintRadius=inpaint_radius, flags=cv2.INPAINT_TELEA)

    # Сохранение результата
    cv2.imwrite(output_path, image)
    print(f"Изображение сохранено как {output_path}")
    return True

def process_folder(input_folder, output_folder):
    # Проверка существования папок
    if not os.path.exists(input_folder):
        print(f"Ошибка: Папка '{input_folder}' не найдена.")
        return

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Обработка всех изображений в папке
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            input_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)
            detect_and_fill_black_areas(input_path, output_path)

# Пример использования
input_folder = 'blood_analysis_dataset_540/paper'
output_folder = 'blood_analysis_dataset_540/processed'
process_folder(input_folder, output_folder)
# Out:
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498585.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/2F7E2606-DDD0-41D6-A944-621C93B78E10.JPG
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498587.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498584.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5253491034988603366.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5251729535756530392.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135968.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135959.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_6301.png
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5251729535756530393.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_6308_filled.jpg
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_6308.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135961.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5224292219517791658.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5249112771096864886.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135965.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия 4756C4C1-D146-4B0C-9BEB-B9A1AA1DC328.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498601.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5253981335570216089.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия E1408970-45B6-4F42-8EED-E36B6D1E7259.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135960.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135982.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498596.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_8086.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498597.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135980.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498586.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/23de5499-a939-4e90-9370-22736299f094.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135971.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5249086554616490419.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498588.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498592.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/0858237f-6bf4-454c-9e88-e9d17b79455a.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5249112771096864887.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/2025-02-01_22-13-19.png. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия 4771E015-2417-4047-87E8-67B0712BF68E.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135958.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5224292219517791654.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия 41F389B4-A116-4492-AB41-514C2AD0C991.jpeg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135988.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135985.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498605.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498604.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5253491034988603368.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_7244.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/2025-02-01_22-11-10.png. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5249460521713919632.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5251729535756529308.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5251729535756530401.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498591.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_8513.jpg
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_6400.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5253491034988603367.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135993.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135970.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5251729535756529310.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5249460521713919630.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_6662.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498595.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498593.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5224292219517791650.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_6304.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5249112771096864885.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5224292219517791657.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256188785551601203.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/5249460521713919633.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135975.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5224292219517791661.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135973.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135984.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135990.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_6310.jpg
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_6663.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5224292219517791660.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия EE56E931-F1C8-46A5-85A8-B1FA5948BF2D.png
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5222040419704106456.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498598.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135977.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия AA6D2007-828B-4CBE-A1A9-4F624163CDA7.jpg
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_6401.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498602.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498603.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498599.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135957.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/2025-02-01_22-12-15.png. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135989.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5224292219517791662.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/2025-02-01_22-14-38.png. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5224292219517791653.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498589.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/IMG_6374.JPG. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_6402.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5224292219517791659.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135991.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498594.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_6303.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5224292219517791649.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия 8A79AFF4-1243-4A84-B5B8-E03D1416EC34.jpg
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия D977F8B2-4519-4F23-AA9D-4ABE15ACD305.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135987.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_4980.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135983.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5251729535756530402.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_6186.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135969.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135992.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135967.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5224292219517791656.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135981.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135963.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498600.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135976.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5249086554616490369.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5256043418088498590.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135964.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135979.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135986.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_6306.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5258006432891135962.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия D94C40A7-7ADE-4749-9035-4272478CD79F.jpg
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5249086554616490368.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5253491034988603811.jpg. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/2025-02-01_22-13-57.png. Файл будет скопирован.
# Не найдено подходящих черных областей в blood_analysis_dataset_540/paper/5249460521713919628.jpg. Файл будет скопирован.
# Изображение сохранено как blood_analysis_dataset_540/processed/Копия IMG_8306.jpg
